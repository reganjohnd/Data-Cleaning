# %%
import pandas as pd
import re
from datetime import datetime

import ProjectA_ElectronicsStore_TransactionalData as pA
import helper_functions as hf

import logging

# logging.basicConfig(level=logging.DEBUG, filename='G:\\My Drive\\DANIELS ECOSYSTEM\\extracurricularActivities\\DataScience\\Projects\\Transactional Retail Dataset of Electronics Store\\tmp.log')

# %%
df = pd.read_csv(hf.create_dir('G:\My Drive\DANIELS ECOSYSTEM\extracurricularActivities\DataScience\datasets\Transactional Retail Dataset of Electronics Store', 'test_output.csv'))
# hf.create_dir('G:\My Drive\DANIELS ECOSYSTEM\extracurricularActivities\DataScience\datasets\Transactional Retail Dataset of Electronics Store', 'test_output.csv')
df.head()
# Out:
#     order_id   customer_id        date nearest_warehouse  \
# 0  ORD473815  ID0588198721  2019-03-13         Nickolson
# 1  ORD347594  ID0332796790  2019-04-01            Bakers
# 2  ORD293148  ID1681675856  2019-12-09         Nickolson
# 3  ORD239025  ID1449308562  2019-06-29            Bakers
# 4  ORD197167  ID0377544391  2019-09-04          Thompson
#
#                                        shopping_cart  order_price  \
# 0               [('Thunder line', 1), ('pearTV', 1)]         8490
# 1  [('Lucent 330S', 2), ('pearTV', 2), ('iAssist ...        35205
# 2        [('Toshika 750', 1), ('Candle Inferno', 2)]         5180
# 3  [('Thunder line', 1), ('pearTV', 2), ('Lucent ...        17260
# 4  [('Thunder line', 2), ('Alcon 10', 1), ('Lucen...        23180
#
#    delivery_charges  customer_lat  customer_long  coupon_discount  \
# 0             66.07    -37.812137     144.973992                5
# 1             73.58    -37.808563     145.000167               10
# 2             80.53    -37.809841     144.976329               25
# 3             64.30    -37.817536     144.989861               15
# 4             64.98    -37.815584     144.945277               25
#
#    order_total  season  is_expedited_delivery  distance_to_nearest_warehouse  \
# 0      8131.57  Autumn                  False                         0.8182
# 1     31758.08  Summer                   True                         0.4624
# 2      3965.53  Spring                  False                         1.1423
# 3     14735.30  Winter                  False                         0.9631
# 4     17449.98  Autumn                  False                         0.3603
#
#                               latest_customer_review  is_happy_customer
# 0  awesome phone! great phone! the screen is a ni...               True
# 1  not as advertised was not actually unlocked an...              False
# 2  great build qualitygood screen resolution for ...               True
# 3  wife loves it. got this as a gift for my wife ...               True
# 4  super phone within days of receiving this phon...               True

# %%
remove = ['-', ' ']
for i in remove:
    data['date'] = [x.replace(i, '/') for x in data['date']]
# Out:
# t

# %%
data['toggle'] = ["1" for x in data['date'] if re.match(r'^\d{4}', x) is None else "ArithmeticError0"]
# Out:
#   Input In [11]
#     data['toggle'] = [1 for x in data['date'] if re.search(r'^\d{4}', x) else 0]
#                                                                          ^
# SyntaxError: invalid syntax

# %%
x = datetime.strptime(data['date'][43], '%m/%d/%Y')
datetime.strftime(x, '%Y/%m/%d')
# Out:
# '2019/03/13'

# %%
data['date'] = [datetime.strptime(x, '%m/%d/%Y') for x in data['date'] if re.search(r'^\d{4}', x)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\regan\OneDrive - 22Seven Digital\5-scripts\Github\Data-Cleaning\Shop A_Electronics_store_transactional.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/regan/OneDrive%20-%2022Seven%20Digital/5-scripts/Github/Data-Cleaning/Shop%20A_Electronics_store_transactional.ipynb#ch0000004?line=0'>1</a> data['date'] = [datetime.strptime(x, '%m/%d/%Y') for x in data['date'] if re.search(r'^\d{4}', x)]
#
# c:\Users\regan\OneDrive - 22Seven Digital\5-scripts\Github\Data-Cleaning\Shop A_Electronics_store_transactional.ipynb Cell 8 in <listcomp>(.0)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/regan/OneDrive%20-%2022Seven%20Digital/5-scripts/Github/Data-Cleaning/Shop%20A_Electronics_store_transactional.ipynb#ch0000004?line=0'>1</a> data['date'] = [datetime.strptime(x, '%m/%d/%Y') for x in data['date'] if re.search(r'^\d{4}', x)]
#
# File c:\Python\Python310\lib\_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File c:\Python\Python310\lib\_strptime.py:349, in _strptime(data_string, format)
#     347 found = format_regex.match(data_string)
#     348 if not found:
# --> 349     raise ValueError("time data %r does not match format %r" %
#     350                      (data_string, format))
#     351 if len(data_string) != found.end():
#     352     raise ValueError("unconverted data remains: %s" %
#     353                       data_string[found.end():])
#
# ValueError: time data '2019-06-22' does not match format '%m/%d/%Y'

# %%
def date_cleaning(data, correct_date_format):
    bad_dates = data[~data['date'].str.contains(r'^\d{4}')]
    good_dates = data[data['date'].str.contains(r'^\d{4}')]

    remove = ['-', ' ']
    for i in remove:
        bad_dates['date'] = [x.replace(i, '/') for x in bad_dates['date']]

    bad_dates['date'] = [datetime.strptime(x, '%m/%d/%Y') for x in bad_dates['date']]
    bad_dates['date'] = [datetime.strftime(x, correct_date_format) for x in bad_dates['date']]
    return pd.concat([bad_dates, good_dates])

# %%
output = pA.date_cleaning(df, '%Y-%m-%d')
output
# Out:
# c:\Users\regan\OneDrive - 22Seven Digital\5-scripts\Github\Data-Cleaning\ProjectA_ElectronicsStore_TransactionalData.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bad_dates['date'] = [x.replace(i, '/') for x in bad_dates['date']]
# c:\Users\regan\OneDrive - 22Seven Digital\5-scripts\Github\Data-Cleaning\ProjectA_ElectronicsStore_TransactionalData.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bad_dates['date'] = [datetime.strptime(x, '%m/%d/%Y') for x in bad_dates['date']]
# c:\Users\regan\OneDrive - 22Seven Digital\5-scripts\Github\Data-Cleaning\ProjectA_ElectronicsStore_TransactionalData.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bad_dates['date'] = [datetime.strftime(x, correct_date_format) for x in bad_dates['date']]
#       order_id   customer_id        date nearest_warehouse  \
# 43   ORD473815  ID0588198721  2019-03-13         Nickolson
# 78   ORD347594  ID0332796790  2019-04-01            Bakers
# 114  ORD293148  ID1681675856  2019-12-09         Nickolson
# 124  ORD239025  ID1449308562  2019-06-29            Bakers
# 136  ORD197167  ID0377544391  2019-09-04          Thompson
# ..         ...           ...         ...               ...
# 494  ORD379700  ID2190564628  2019-08-05         Nickolson
# 495  ORD475510  ID0247417082  2019-08-07         Nickolson
# 497  ORD079320  ID2707985442  2019-10-16         Nickolson
# 498  ORD026546  ID0060088412  2019-05-19         Nickolson
# 499  ORD085447  ID5257193650  2019-05-25            Bakers
#
#                                          shopping_cart  order_price  \
# 43                [('Thunder line', 1), ('pearTV', 1)]         8490
# 78   [('Lucent 330S', 2), ('pearTV', 2), ('iAssist ...        35205
# 114        [('Toshika 750', 1), ('Candle Inferno', 2)]         5180
# 124  [('Thunder line', 1), ('pearTV', 2), ('Lucent ...        17260
# 136  [('Thunder line', 2), ('Alcon 10', 1), ('Lucen...        23180
# ..                                                 ...          ...
# 494  [('Candle Inferno', 1), ('Alcon 10', 1), ('Luc...        17510
# 495             [('Alcon 10', 2), ('iAssist Line', 2)]       386776
# 497  [('pearTV', 1), ('Alcon 10', 1), ('Lucent 330S...        16490
# 498  [('iStream', 1), ('Candle Inferno', 1), ('iAss...         5030
# 499  [('iStream', 1), ('Toshika 750', 1), ('Alcon 1...        22370
#
#      delivery_charges  customer_lat  customer_long  coupon_discount  \
# 43              66.07    -37.812137     144.973992                5
# 78              73.58    -37.808563     145.000167               10
# 114             80.53    -37.809841     144.976329               25
# 124             64.30    -37.817536     144.989861               15
# 136             64.98    -37.815584     144.945277               25
# ..                ...           ...            ...              ...
# 494             75.37    -37.816209     144.964057                5
# 495             59.70    -37.817662     144.970405               10
# 497            106.98    -37.805979     144.966101                0
# 498             79.89     37.820071     144.984435               10
# 499             64.62    -37.812231     144.988679               15
#
#      order_total  season  is_expedited_delivery  \
# 43       8131.57  Autumn                  False
# 78      31758.08  Summer                   True
# 114      3965.53  Spring                  False
# 124     14735.30  Winter                  False
# 136     17449.98  Autumn                  False
# ..           ...     ...                    ...
# 494     16709.87  Winter                   True
# 495     20174.70  Winter                   True
# 497     16596.98  Spring                   True
# 498      4606.89  Autumn                   True
# 499     19079.12  Autumn                   True
#
#      distance_to_nearest_warehouse  \
# 43                          0.8182
# 78                          0.4624
# 114                         1.1423
# 124                         0.9631
# 136                         0.3603
# ..                             ...
# 494                         0.5513
# 495                         0.1282
# 497                         1.4368
# 498                         1.3191
# 499                         0.6277
#
#                                 latest_customer_review  is_happy_customer
# 43   awesome phone! great phone! the screen is a ni...               True
# 78   not as advertised was not actually unlocked an...              False
# 114  great build qualitygood screen resolution for ...               True
# 124  wife loves it. got this as a gift for my wife ...               True
# 136  super phone within days of receiving this phon...               True
# ..                                                 ...                ...
# 494  good quality price ratio bought it for my mom,...               True
# 495  i bought this phone to send to my sister in .....              False
# 497          love this phone! has many great features!               True
# 498  spoiled son's birthday present son wanted one ...               True
# 499  two stars the phone is way smaller then it loo...              False
#
# [500 rows x 16 columns]

# %%
len(df[~df['date'].str.contains(r'^\d{4}')])
# Out:
# 20

# %%
OUTPUT_DIR = 'G:\\My Drive\\DANIELS ECOSYSTEM\\extracurricularActivities\\DataScience\\datasets\\Transactional Retail Dataset of Electronics Store\\'
# logging.basicConfig(level=logging.WARNING, filename=f'{OUTPUT_DIR}warnings.log')

# def date_cleaning(data, correct_date_format):
#     '''
#     correct date format: YYYY-mm-dd
#     '''
#     bad_dates = data[~data['date'].str.contains(r'^\d{4}')]
#     good_dates = data[data['date'].str.contains(r'^\d{4}')]

#     remove = ['-', ' ']
#     for i in remove:
#         bad_dates['date'] = [x.replace(i, '/') for x in bad_dates['date']]

#     try:
#         bad_dates['date'] = [datetime.strptime(x, '%m/%d/%Y') for x in bad_dates['date']]
#         bad_dates['date'] = [datetime.strftime(x, correct_date_format) for x in bad_dates['date']]
#     except:
        

#     output = pd.concat([bad_dates, good_dates])

#     if len(output[~output['date'].str.contains(r'^\d{4}')]) != 0:
#         logging.warning('All faulty date formatting was not identified')

#     return output

    
# df = pd.read_csv(f'{OUTPUT_DIR}dirty_data.csv')
# date_cleaning(df, '%Y-%m-%d').to_csv(f'{OUTPUT_DIR}test_output.csv', index=False)

# %%
data = pd.read_csv(f'{OUTPUT_DIR}dirty_data_test.csv')

# %%
# df['shopping_cart'] = df['shopping_cart'].apply(lambda x: eval(x))
df.columns
# Out:
# Index(['order_id', 'customer_id', 'date', 'nearest_warehouse', 'shopping_cart',
#        'order_price', 'delivery_charges', 'customer_lat', 'customer_long',
#        'coupon_discount', 'order_total', 'season', 'is_expedited_delivery',
#        'distance_to_nearest_warehouse', 'latest_customer_review',
#        'is_happy_customer'],
#       dtype='object')

# %%
OUTPUT_DIR = 'G:\\My Drive\\DANIELS ECOSYSTEM\\extracurricularActivities\\DataScience\\datasets\\Transactional Retail Dataset of Electronics Store\\'
data = pd.read_csv(f'{OUTPUT_DIR}dirty_data.csv')
data = pA.date_cleaning(data, '%Y/%m/%d')

# def product_sales_by_month(data):
#     # Analyse shopping cart

#     # isolate required fields
#     tmp_df = data[['order_id', 'customer_id', 'date', 'shopping_cart']]
#     # cleaning
#     tmp_df['shopping_cart'] = [eval(x) for x in tmp_df['shopping_cart']]
#     df_stack = tmp_df.explode('shopping_cart').reset_index()
#     df_stack['quantity'] = [x[1] for x in df_stack['shopping_cart']]
#     df_stack['shopping_cart'] = [x[0].upper() for x in df_stack['shopping_cart']]


#     df_stack['date'] = [datetime.strptime(x.replace('-', '/'), '%Y/%m/%d') for x in df_stack['date']]
#     # df_stack['date'] = [datetime.strptime(x, '%Y/%m/%d') for x in df_stack['date']]
#     df_stack = df_stack.sort_values(by='date')

#     tmp = df_stack[['date', 'shopping_cart', 'quantity']]
#     tmp['date'] = [x.to_period('M') for x in tmp['date']]
#     tmp = tmp.groupby(['date', 'shopping_cart']).sum()
#     # tmp = tmp.reset_index().to_csv(hf.create_dir(OUTPUT_DIR, 'prod_count_by_month.csv'), index=False)
#     return tmp

# product_sales_by_month(data).to_csv('C:\\Users\\regan\\OneDrive - 22Seven Digital\\1. Admin\\test.csv', index=False)
# Out:
# c:\Users\regan\OneDrive - 22Seven Digital\5-scripts\Github\Data-Cleaning\ProjectA_ElectronicsStore_TransactionalData.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bad_dates['date'] = [x.replace(i, '/') for x in bad_dates['date']]
# c:\Users\regan\OneDrive - 22Seven Digital\5-scripts\Github\Data-Cleaning\ProjectA_ElectronicsStore_TransactionalData.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bad_dates['date'] = [datetime.strptime(x, '%m/%d/%Y') for x in bad_dates['date']]
# c:\Users\regan\OneDrive - 22Seven Digital\5-scripts\Github\Data-Cleaning\ProjectA_ElectronicsStore_TransactionalData.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bad_dates['date'] = [datetime.strftime(x, correct_date_format) for x in bad_dates['date']]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\regan\OneDrive - 22Seven Digital\5-scripts\Github\Data-Cleaning\testing.ipynb Cell 14 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/regan/OneDrive%20-%2022Seven%20Digital/5-scripts/Github/Data-Cleaning/testing.ipynb#ch0000013?line=0'>1</a> OUTPUT_DIR = 'G:\\My Drive\\DANIELS ECOSYSTEM\\extracurricularActivities\\DataScience\\datasets\\Transactional Retail Dataset of Electronics Store\\'
#       <a href='vscode-notebook-cell:/c%3A/Users/regan/OneDrive%20-%2022Seven%20Digital/5-scripts/Github/Data-Cleaning/testing.ipynb#ch0000013?line=1'>2</a> data = pd.read_csv(f'{OUTPUT_DIR}dirty_data.csv')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/regan/OneDrive%20-%2022Seven%20Digital/5-scripts/Github/Data-Cleaning/testing.ipynb#ch0000013?line=2'>3</a> data = pA.date_cleaning(data, '%Y/%m/%d')
#
# File c:\Users\regan\OneDrive - 22Seven Digital\5-scripts\Github\Data-Cleaning\ProjectA_ElectronicsStore_TransactionalData.py:38, in date_cleaning(data, correct_date_format)
#      36     error_dates.to_csv(f'{OUTPUT_DIR}error_dates.csv')
#      37 finally:
# ---> 38     bad_dates['date'] = [datetime.strptime(x, '%m/%d/%Y') for x in bad_dates['date']]
#      39     bad_dates['date'] = [datetime.strftime(x, correct_date_format) for x in bad_dates['date']]
#      41 output = pd.concat([bad_dates, good_dates])
#
# File c:\Users\regan\OneDrive - 22Seven Digital\5-scripts\Github\Data-Cleaning\ProjectA_ElectronicsStore_TransactionalData.py:38, in <listcomp>(.0)
#      36     error_dates.to_csv(f'{OUTPUT_DIR}error_dates.csv')
#      37 finally:
# ---> 38     bad_dates['date'] = [datetime.strptime(x, '%m/%d/%Y') for x in bad_dates['date']]
#      39     bad_dates['date'] = [datetime.strftime(x, correct_date_format) for x in bad_dates['date']]
#      41 output = pd.concat([bad_dates, good_dates])
#
# File c:\Python\Python310\lib\_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File c:\Python\Python310\lib\_strptime.py:349, in _strptime(data_string, format)
#     347 found = format_regex.match(data_string)
#     348 if not found:
# --> 349     raise ValueError("time data %r does not match format %r" %
#     350                      (data_string, format))
#     351 if len(data_string) != found.end():
#     352     raise ValueError("unconverted data remains: %s" %
#     353                       data_string[found.end():])
#
# ValueError: time data '2019/03/13' does not match format '%m/%d/%Y'

# %%
bad_dates = data[~data['date'].str.contains(r'^\d{4}')]
good_dates = data[data['date'].str.contains(r'^\d{4}')]

remove = ['-', ' ', '*']
for i in remove:
    bad_dates['date'] = [x.replace(i, '/') for x in bad_dates['date']]

bad_dates['date'] = [datetime.strptime(x, '%m/%d/%Y') for x in bad_dates['date']]
bad_dates['date'] = [datetime.strftime(x, '%Y/%m/%d') for x in bad_dates['date']]
# Out:
# C:\Users\regan\AppData\Local\Temp\ipykernel_21224\2003425733.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bad_dates['date'] = [x.replace(i, '/') for x in bad_dates['date']]
# C:\Users\regan\AppData\Local\Temp\ipykernel_21224\2003425733.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bad_dates['date'] = [datetime.strptime(x, '%m/%d/%Y') for x in bad_dates['date']]
# C:\Users\regan\AppData\Local\Temp\ipykernel_21224\2003425733.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bad_dates['date'] = [datetime.strftime(x, '%Y/%m/%d') for x in bad_dates['date']]

# %%
tmp_df = data[['order_id', 'customer_id', 'date', 'shopping_cart']]
# cleaning
tmp_df['shopping_cart'] = [eval(x) for x in tmp_df['shopping_cart']]
df_stack = tmp_df.explode('shopping_cart').reset_index()
df_stack['quantity'] = [x[1] for x in df_stack['shopping_cart']]
df_stack['shopping_cart'] = [x[0].upper() for x in df_stack['shopping_cart']]


df_stack['date'] = [datetime.strptime(x.replace('-', '/'), '%Y/%m/%d') for x in df_stack['date']]
# df_stack['date'] = [datetime.strptime(x, '%Y/%m/%d') for x in df_stack['date']]
df_stack = df_stack.sort_values(by='date')

tmp = df_stack[['date', 'shopping_cart', 'quantity']]
tmp['date'] = [x.to_period('M') for x in tmp['date']]
tmp = tmp.groupby(['date', 'shopping_cart']).sum()
tmp

# data = pA.date_cleaning(data, '%Y/%m/%d')
# product_sales_by_month(data)
# Out:
# C:\Users\regan\AppData\Local\Temp\ipykernel_20568\2818930102.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['shopping_cart'] = [eval(x) for x in tmp_df['shopping_cart']]
# C:\Users\regan\AppData\Local\Temp\ipykernel_20568\2818930102.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp['date'] = [x.to_period('M') for x in tmp['date']]

# %%
datetime.strptime(df_stack['date'][0], '%Y-%m-%d')
# Out:
# datetime.datetime(2019, 3, 13, 0, 0)

# %%
str(df_stack['date'][0].year) + str(df_stack['date'][0].month)
# Out:
# '20193'

# %%
df_stack['yearMonth'] = [str(x.year) + str(x.month) for x in df_stack['date']]
# Out:
#       index   order_id   customer_id       date   shopping_cart  quantity  \
# 0         0  ORD473815  ID0588198721 2019-03-13    THUNDER LINE         1
# 1         0  ORD473815  ID0588198721 2019-03-13          PEARTV         1
# 2         1  ORD347594  ID0332796790 2019-04-01     LUCENT 330S         2
# 3         1  ORD347594  ID0332796790 2019-04-01          PEARTV         2
# 4         1  ORD347594  ID0332796790 2019-04-01    IASSIST LINE         1
# ...     ...        ...           ...        ...             ...       ...
# 1501    497  ORD026546  ID0060088412 2019-05-19  CANDLE INFERNO         1
# 1502    497  ORD026546  ID0060088412 2019-05-19    IASSIST LINE         2
# 1503    498  ORD085447  ID5257193650 2019-05-25         ISTREAM         1
# 1504    498  ORD085447  ID5257193650 2019-05-25     TOSHIKA 750         1
# 1505    498  ORD085447  ID5257193650 2019-05-25        ALCON 10         2
#
#      yearMonth
# 0        20193
# 1        20193
# 2        20194
# 3        20194
# 4        20194
# ...        ...
# 1501     20195
# 1502     20195
# 1503     20195
# 1504     20195
# 1505     20195
#
# [1506 rows x 7 columns]

# %%
# df_stack.groupby(['yearMonth', 'shopping_cart']).sum()
# Out:
# C:\Users\regan\AppData\Local\Temp\ipykernel_20568\2918812847.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp['date'] = [x.to_period('M') for x in tmp['date']]

# %%
df['exclamation_count'] = [len(re.findall('!', x)) for x in df.latest_customer_review]
df['shopping_cart'] = df['shopping_cart'].apply(lambda x: eval(x))

# %%
# Out:
#        date shopping_cart  quantity
# 0   2019-01      ALCON 10        16
# 30  2019-04      ALCON 10        23
